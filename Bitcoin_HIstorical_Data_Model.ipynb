# 362  08-02-2022  43854.65234  45293.86719  42807.83594  44118.44531
# 363  09-02-2022  44096.70313  44727.80078  43232.96875  44338.79688
# 364  10-02-2022  44347.80078  45661.17188  43402.80859  43565.11328
# 365  11-02-2022  43474.11328  43810.17188  42950.69922  43592.44922
#
#        Adj Close        Volume
# 0    47909.33203  8.138891e+10
# 1    47504.85156  7.655504e+10
# 2    47105.51563  7.025046e+10
# ...

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 361    49637.158165
# 362    49465.153048
# 363    49298.496954
# 364    49101.884063
# 365    48908.108087
# Name: Close, Length: 366, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')

# %%
ma300 = df.Close.rolling(300).mean()
ma300
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 361    46746.091003
# 362    46682.786837
# 363    46619.536121
# 364    46559.510535
# 365    46502.539298
# Name: Close, Length: 366, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma300,'r')

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,'r')
plt.plot(ma300,'g')

# %%
df.shape
# Out:
# (366, 7)

# %%
data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (256, 1)
# (110, 1)

# %%
data_training.head()
# Out:
#          Close
# 0  47909.33203
# 1  47504.85156
# 2  47105.51563
# 3  48717.28906
# 4  47945.05859

# %%
data_testing.head()
# Out:
#            Close
# 256  63039.82422
# 257  60363.79297
# 258  58482.38672
# 259  60622.13672
# 260  62227.96484

# %%
from sklearn.preprocessing import MinMaxScaler
scaler =  MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.50025536],
#        [0.48907738],
#        [0.47804158],
#        [0.52258356],
#        [0.50124267],
#        [0.5359199 ],
#        [0.61742044],
#        [0.60445362],
#        [0.72075261],
#        [0.72659436],
#        [0.76640109],
#        [0.67430271],
#        [0.52554433],
#        [0.54988851],
#        [0.47771924],
#        [0.45687967],
#        [0.4526982 ],
#        [0.42366215],
#        [0.54784101],
#        [0.51323449],
#        [0.57290631],
#        [0.5182691 ],
#        [0.52838743],
#        [0.52797505],
#        [0.59137916],
#        [0.62011532],
#        [0.69134813],
#        [0.72408041],
#        [0.77372933],
#        [0.76065692],
#        [0.86873882],
#        [0.8151049 ],
#        [0.72127952],
#        [0.74608789],
#        [0.80318239],
#        [0.77521613],
#        [0.78869475],
#        [0.78778257],
#        [0.76594446],
#        [0.68319644],
#        [0.68899437],
#        [0.63469968],
#        [0.6051269 ],
# ...

# %%
data_training_array.shape
# Out:
# (256, 1)

# %%
x_train = []
y_train = []

for i in range(100,data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])
x_train,y_train = np.array(x_train),np.array(y_train)

# %%
x_train.shape
# Out:
# (156, 100, 1)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
to_row = int(len(df)*0.9)

training_data=list(df[0:to_row]['Close'])
testing_data=list(df[to_row:]['Close'])
testing_data
# Out:
# [43160.92969,
#  41557.90234,
#  41733.94141,
#  41911.60156,
#  41821.26172,
#  42735.85547,
#  43949.10156,
#  42591.57031,
#  43099.69922,
#  43177.39844,
#  43113.87891,
#  42250.55078,
#  42375.63281,
#  41744.32813,
#  40680.41797,
#  36457.31641,
#  35030.25,
#  36276.80469,
#  36654.32813,
#  36954.00391,
#  36852.12109,
#  37138.23438,
#  37784.33203,
#  38138.17969,
#  37917.60156,
#  38483.125,
#  38743.27344,
#  36952.98438,
#  37154.60156,
#  41500.875,
#  41441.16406,
#  42412.43359,
#  43840.28516,
#  44118.44531,
#  44338.79688,
#  43565.11328,
#  43592.44922]

# %%
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('Close')
plt.plot(df[0:to_row]['Close'],'green',label='Train data')
plt.plot(df[to_row:]['Close'],'blue',label='Test data')
plt.legend()

# %%
model_predictions = []
n_test_obser = len(testing_data)

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
for i in range(n_test_obser):
    model = ARIMA(training_data,order=(4,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    print(output)
    break
# Out:
# (array([43662.32551647]), array([1863.96615939]), array([[40009.01897566, 47315.63205728]]))
# C:\Users\SWARNAPRAVA\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
output
# Out:
# (array([43662.32551647]),
#  array([1863.96615939]),
#  array([[40009.01897566, 47315.63205728]]))

# %%
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                    D.y   No. Observations:                  328
# Model:                 ARIMA(4, 1, 0)   Log Likelihood               -2935.414
# Method:                       css-mle   S.D. of innovations           1863.966
# Date:                Fri, 11 Feb 2022   AIC                           5882.827
# Time:                        22:02:12   BIC                           5905.585
# Sample:                             1   HQIC                          5891.907
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -13.2327    104.478     -0.127      0.899    -218.006     191.541
# ar.L1.D.y     -0.0561      0.055     -1.017      0.309      -0.164       0.052
# ar.L2.D.y      0.0121      0.055      0.219      0.827      -0.096       0.120
# ...

# %%
plt.figure(figsize=(15,9))
plt.grid(True)
data_range = df[to_row:].index

plt.plot(df[0:to_row]['Close'],linestyle='dashed',color= 'blue',label='forecast')
plt.legend()
plt.title('bitcoin forecast')
plt.plot(df[to_row:]['Close'],linestyle='dashed',color='red',label='BTC Forecasting')
plt.show()
